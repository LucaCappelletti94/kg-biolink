# %%
from grape import Graph, GraphVisualizer

# %%
kg = Graph.from_csv(
    node_path="kg_biolink_nodes_3.4.3.tsv",
    nodes_column="node_name",
    node_list_node_types_column="node_type",
    node_types_separator="|",
    edge_path="kg_biolink_edges_3.4.3.tsv",
    sources_column="source",
    destinations_column="destination",
    edge_list_edge_types_column="edge_type",
    name="KGBioLink",
    directed=False
)

# %%
kg
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>KGBioLink</h2><p class="paragraph">The undirected multigraph KGBioLink has 2.44K heterogeneous nodes and 3.97K heterogeneous edges. The graph contains 32 connected components (of which 23 are disconnected nodes), with the largest one containing 2.38K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 312.43KB and 51.41KB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 184, the mode degree is 1, the mean degree is 3.25 and the node degree median is 1.</p><p class="paragraph">The nodes with the highest degree centrality are translator_minimal (degree 184 and unknown node type), coexists with (degree 173 and unknown node type), related to (degree 115 and node types named thing and named thing), related to at instance level (degree 94 and unknown node type) and association (degree 83 and unknown node type).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 93 node types, of which the 10 most common are named thing (63 nodes, 2.58%), sequence variant (34 nodes, 1.39%), genomic entity (33 nodes, 1.35%), association (27 nodes, 1.10%), disease or phenotypic feature (26 nodes, 1.06%), gene or gene product (25 nodes, 1.02%), integer (21 nodes, 0.86%), publication (18 nodes, 0.74%), ontology class (18 nodes, 0.74%) and uriorcurie (17 nodes, 0.70%). The node types are multi-label, and the node with most node types has 2 node types. The RAM requirement for the node types data structure is 84.97KB.</p><h4 style="margin: 1em 0 0 0;">Isomorphic node types</h4><p class="paragraph">Isomorphic node types groups are node types describing exactly the same set of nodes. The presence of such duplicated node types suggests a potential modelling error in the pipeline that has produced this graph. 1 isomorphic node types groups were detected in this graph.</p><ol><li><p class="paragraph">Isomorphic node type group containing 2 node types (), which are: coding sequence and PhaseEnum.</p></li></ol><h4 style="margin: 1em 0 0 0;">Singleton node types</h4><p class="paragraph">Singleton node types are node types that are assigned exclusively to a single node, making the node type relatively meaningless, as it adds no more information than the node name itself. The graph contains 37 singleton node types, which are ReactionSideEnum (reaction side (degree 2 and node type ReactionSideEnum)), organismal entity (has receptor (degree 2 and node types exposure event and organismal entity)), unit (has unit (degree 11 and node types quantity value and unit)), device (has device (degree 4 and node type device)), FDAIDAAdverseEventEnum (FDA adverse event level (degree 2 and node type FDAIDAAdverseEventEnum)), ResourceRoleEnum (resource role (degree 3 and node types retrieval source and ResourceRoleEnum)), taxonomic rank (has taxonomic rank (degree 2 and node type taxonomic rank)), book chapter (chapter (degre ...
# <li><p class="paragraph">duration (node type time type)</p></li>
# <li><p class="paragraph">narrow matches (unknown node type)</p></li>
# <li><p class="paragraph">statement property (node type association)</p></li>
# <li><p class="paragraph">  IF (unknown node type)</p></li>
# <li><p class="paragraph">This field is multi-valued. It should include values for ancestors of the biolink class; for example, a protein such as Shh would have category values `biolink:Protein`, `biolink:GeneProduct`, `biolink:MolecularEntity`, ... (unknown node type)</p></li>
# <li><p class="paragraph">  R type Reaction (unknown node type)</p></li>
# <li><p class="paragraph"> * In a neo4j database this MAY correspond to the neo4j label tag. (unknown node type)</p></li>
# <li><p class="paragraph">edge qualifier (node type association)</p></li>
# <li><p class="paragraph">  R has-output C2 AND (unknown node type)</p></li>
# <li><p class="paragraph">  C1 derives-into C2 &lt;&lt;catalyst qualifier P&gt;&gt;&quot; (unknown node type)</p></li>
# <li><p class="paragraph">chemical formula value (unknown node type)</p></li>
# <li><p class="paragraph">broad matches (unknown node type)</p></li>
# <li><p class="paragraph">node qualifier (node type association)</p></li>
# <li><p class="paragraph"> # TODO: add examples of values for this property.&quot; (unknown node type)</p></li></ul><p class="paragraph">And other 8 singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 3 node tuples in the graph, involving a total of 6 nodes (0.25%) and 3 edges (0.04%). The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes time type (unknown node type) and time (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24432' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24432'>CHEBI:24432</a> (unknown node type) and biological role mixin (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes mapping collection (unknown node type) and predicate mappings (node type predicate mapping).</p></li></ul><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic node groups are nodes with exactly the same neighbours, node types, edge types and weights (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 7 isomorphic node groups in the graph, involving a total of 22 nodes (0.90%) and 387 edges (4.87%), with the largest one involving 5 nodes and 115 edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 5 nodes (degree 23 and unknown node type): sign, trait, symptom, endophenotype and phenotype.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 28 and node types chemical or drug or treatment and disease or phenotypic feature): indicated for and is substance that treats.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 18 and unknown node type): information artefact, information entity and information.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 18 and unknown node type): disorder, medical condition and condition.</p></li>
# <li><p class="paragraph">Group with 5 nodes (degree 10 and unknown node type): realized in response to, disease caused by disruption of, caused by, disease has basis in dysfunction of and realized in response to stimulus.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 18 and unknown node type): chemical substance and small molecule.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 11 and unknown node type): agent and group.</p></li></ol><h4 style="margin: 1em 0 0 0;">Trees</h4><p class="paragraph">A tree is a connected component with <code>n</code> nodes and <code>n-1</code> edges. We have detected  a single tree in the graph, involving a total of 10 nodes (0.41%) and 18 edges (0.23%).</p><ul class="large-columns"><li><p class="paragraph">Tree starting from the root node epidemiological outcome (degree 2), and containing 10 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/NCIT_C19291' target='_blank' title='Go to NCI Thesaurus OBO Edition to get more informations about NCIT:C19291'>NCIT:C19291</a>, outcome (degree 8), pathological process outcome, hospitalization outcome and disease or phenotypic feature outcome. Its edges have 2 edge types, which are mixins (15 edges, 93.75%) and related_mappings.</p></li></ul><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 17 dendritic trees in the graph, involving a total of 299 nodes (12.23%) and 598 edges (7.53%), with the largest one involving 50 nodes and 100 edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node association slot (degree 78 and node type association), and containing 50 nodes, with a maximal depth of 2, which are log odds ratio (node type float), concept count object (node type integer), supporting text section type (node type string), supporting data source (unknown node type) and relative frequency object (node type string). Its nodes have 11 node types, of which the 10 most common are integer (11 nodes, 0.45%), string (11 nodes, 0.45%), float (6 nodes, 0.25%), uriorcurie (5 nodes, 0.20%), association (5 nodes, 0.20%), boolean (2 nodes, 0.08%), clinical modifier, confidence level, sequence variant and LogicalInterpretationEnum. Its edges have 2 edge types, which are is_a (52 edges, 83.87%) and exact_mappings (10 edges, 16.13%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node node property (degree 74 and node type named thing), and containing 27 nodes, with a maximal depth of 2, which are retrieved on (node types dataset and date), has constituent (node type molecular entity), download url (node type information content entity), update date (node type date) and has receptor (node types exposure event and organismal entity). Its nodes have 14 node types, of which the 10 most common are label type (3 nodes, 0.12%), named thing (3 nodes, 0.12%), dataset (3 nodes, 0.12%), exposure event (2 nodes, 0.08%), date (2 nodes, 0.08%), dataset summary (2 nodes, 0.08%), dataset version (2 nodes, 0.08%), molecular entity, information content entity and disease or phenotypic feature. Its edges have 4 edge types, which are is_a (17 edges, 45.95%), exact_mappings (12 edges, 32.43%), narrow_mappings (6 edges, 16.22%) and mappings (2 edges, 5.41%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node anatomical entity (degree 30), and containing 25 nodes, with a maximal depth of 2, which are STY:T030, EMAPA:0, cell (degree 7), <a href='http://semanticscience.org/resource/SIO_001262' target='_blank' title='Go to Semantic Science to get more informations about SIO:001262'>SIO:001262</a> and <a href='http://purl.obolibrary.org/obo/WBBT_0000100' target='_blank' title='Go to C. elegans Gross Anatomy Ontology to get more informations about WBbt:0000100'>WBbt:0000100</a>. Its edges have 4 edge types, which are exact_mappings (20 edges, 64.52%), narrow_mappings (9 edges, 29.03%), related_mappings and is_a.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node attribute (degree 28 and unknown node type), and containing 24 nodes, with a maximal depth of 4, which are zygosity (unknown node type), severity value (unknown node type), chemical role (node type A role played by the molecular entity or part thereof within a chemical context.&quot;), clinical attribute (degree 5 and unknown node type) and biological sex (degree 4 and unknown node type). Its nodes have a single node type, which is A role played by the molecular entity or part thereof within a chemical context.&quot;. Its edges have 2 edge types, which are exact_mappings (21 edges, 52.50%) and is_a (19 edges, 47.50%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node cellular organism (degree 8), and containing 23 nodes, with a maximal depth of 2, which are invertebrate (degree 6), fungus (degree 6), vertebrate (degree 5), plant (degree 5) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=131567' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:131567'>NCBITaxon:131567</a>. Its edges have 4 edge types, which are exact_mappings (29 edges, 70.73%), related_mappings (4 edges, 9.76%), narrow_mappings (4 edges, 9.76%) and is_a (4 edges, 9.76%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node physically interacts with (degree 17), and containing 23 nodes, with a maximal depth of 3, which are DRUGBANK:target, WIKIDATA_PROPERTY:P129, <a href='http://identifiers.org/chembl.compound/binding_agent' target='_blank' title='Go to Chembl Compound to get more informations about CHEMBL.MECHANISM:binding_agent'>CHEMBL.MECHANISM:binding_agent</a>, <a href='http://identifiers.org/chembl.compound/cross-linking_agent' target='_blank' title='Go to Chembl Compound to get more informations about CHEMBL.MECHANISM:cross-linking_agent'>CHEMBL.MECHANISM:cross-linking_agent</a> and <a href='http://identifiers.org/chembl.compound/chelating_agent' target='_blank' title='Go to Chembl Compound to get more informations about CHEMBL.MECHANISM:chelating_agent'>CHEMBL.MECHANISM:chelating_agent</a>. Its edges have 5 edge types, which are narrow_mappings (12 edges, 37.50%), close_mappings (9 edges, 28.12%), broad_mappings (5 edges, 15.62%), is_a (4 edges, 12.50%) and exact_mappings (2 edges, 6.25%).</p></li></ol><p class="paragraph">And other 11 dendritic trees.</p><h4 style="margin: 1em 0 0 0;">Stars</h4><p class="paragraph">A star is a tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with a high degree. We have detected 2 stars in the graph, involving a total of 10 nodes (0.41%) and 16 edges (0.20%), with the largest one involving 6 nodes and 10 edges. The detected stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Star starting from the root node double (degree 5), and containing 6 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/UO_0010006' target='_blank' title='Go to Units of measurement ontology to get more informations about UO:0010006'>UO:0010006</a>, <a href='http://purl.obolibrary.org/obo/UO_0000187' target='_blank' title='Go to Units of measurement ontology to get more informations about UO:0000187'>UO:0000187</a>, quotient, ratio and percentage frequency value. Its edges have a single edge type, which is typeof.</p></li>
# <li><p class="paragraph">Star starting from the root node uriorcurie (degree 3), and containing 4 nodes, with a maximal depth of 1, which are category type, predicate type and iri type. Its edges have a single edge type, which is typeof.</p></li></ol><h4 style="margin: 1em 0 0 0;">Dendritic stars</h4><p class="paragraph">A dendritic star is a dendritic tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with high degree and inside a strongly connected component. We have detected 106 dendritic stars in the graph, involving a total of 985 nodes (40.30%) and 1.97K edges (24.80%), with the largest one involving 167 nodes and 334 edges. The detected dendritic stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic star starting from the root node coexists with (degree 173), and containing 167 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/FMA_has_secondary_segmental_supply' target='_blank' title='Go to Foundational Model of Anatomy Ontology (subset) to get more informations about FMA:has_secondary_segmental_supply'>FMA:has_secondary_segmental_supply</a>, <a href='http://purl.obolibrary.org/obo/FMA_insertion_of' target='_blank' title='Go to Foundational Model of Anatomy Ontology (subset) to get more informations about FMA:insertion_of'>FMA:insertion_of</a>, <a href='http://purl.obolibrary.org/obo/FMA_has_primary_segmental_supply' target='_blank' title='Go to Foundational Model of Anatomy Ontology (subset) to get more informations about FMA:has_primary_segmental_supply'>FMA:has_primary_segmental_supply</a>, <a href='http://purl.obolibrary.org/obo/uberon/core#extends_fibers_into' target='_blank' title='Go to Uberon Core to get more informations about UBERON_CORE:extends_fibers_into'>UBERON_CORE:extends_fibers_into</a> and <a href='http://purl.obolibrary.org/obo/FMA_anterosuperior_to' target='_blank' title='Go to Foundational Model of Anatomy Ontology (subset) to get more informations about FMA:anterosuperior_to'>FMA:anterosuperior_to</a>. Its edges have 2 edge types, which are narrow_mappings (166 edges, 99.40%) and exact_mappings.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node related to (degree 115), and containing 100 nodes, with a maximal depth of 1, which are LOINC:has_evaluation, <a href='http://purl.obolibrary.org/obo/RO_0002573' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002573'>RO:0002573</a>, <a href='http://purl.obolibrary.org/obo/RO_0002373' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002373'>RO:0002373</a>, SNOMED:has_modification and UMLS:has_form. Its edges have 3 edge types, which are narrow_mappings (97 edges, 97.00%), exact_mappings (2 edges, 2.00%) and broad_mappings.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node has attribute (degree 78), and containing 75 nodes, with a maximal depth of 1, which are SNOMED:has_dose_form_release_characteristic, CPT:has_possibly_included_panel_element, LOINC:has_aggregation_view, SNOMED:has_inherent_attribute and <a href='http://semanticscience.org/resource/SIO_000008' target='_blank' title='Go to Semantic Science to get more informations about SIO:000008'>SIO:000008</a>. Its edges have 3 edge types, which are narrow_mappings (73 edges, 97.33%), exact_mappings and close_mappings.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node part of (degree 66), and containing 56 nodes, with a maximal depth of 1, which are LOINC:has_supersystem, <a href='http://purl.obolibrary.org/obo/RO_0002571' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002571'>RO:0002571</a>, RXNORM:ingredients_of, <a href='http://purl.obolibrary.org/obo/uberon/core#trunk_part_of' target='_blank' title='Go to Uberon Core to get more informations about UBERON_CORE:trunk_part_of'>UBERON_CORE:trunk_part_of</a> and LOINC:component_of. Its edges have 3 edge types, which are narrow_mappings (47 edges, 83.93%), exact_mappings (6 edges, 10.71%) and broad_mappings (3 edges, 5.36%).</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node located in (degree 48), and containing 41 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/BSPO_0015202' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0015202'>BSPO:0015202</a>, <a href='http://purl.obolibrary.org/obo/BSPO_0000124' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000124'>BSPO:0000124</a>, <a href='http://purl.obolibrary.org/obo/BSPO_0000123' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000123'>BSPO:0000123</a>, <a href='http://purl.obolibrary.org/obo/BSPO_0000125' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000125'>BSPO:0000125</a> and <a href='http://purl.obolibrary.org/obo/NCIT_R40' target='_blank' title='Go to NCI Thesaurus OBO Edition to get more informations about NCIT:R40'>NCIT:R40</a>. Its edges have 2 edge types, which are narrow_mappings (40 edges, 95.24%) and exact_mappings (2 edges, 4.76%).</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node affects (degree 47 and unknown node type), and containing 31 nodes, with a maximal depth of 1, which are UBERGRAPH:is_decrease_of (unknown node type), <a href='http://purl.obolibrary.org/obo/NCIT_R25' target='_blank' title='Go to NCI Thesaurus OBO Edition to get more informations about NCIT:R25'>NCIT:R25</a> (unknown node type), <a href='http://purl.obolibrary.org/obo/NCIT_R101' target='_blank' title='Go to NCI Thesaurus OBO Edition to get more informations about NCIT:R101'>NCIT:R101</a> (unknown node type), <a href='http://purl.obolibrary.org/obo/RO_0012003' target='_blank' title='Go to Relation Ontology to get more informations about RO:0012003'>RO:0012003</a> (unknown node type) and DGIdb:affects (unknown node type). Its nodes have 2 node types, which are disease or phenotypic feature and chemical or drug or treatment. Its edges have 3 edge types, which are narrow_mappings (28 edges, 90.32%), exact_mappings (2 edges, 6.45%) and is_a.</p></li></ol><p class="paragraph">And other 100 dendritic stars.</p><h4 style="margin: 1em 0 0 0;">Dendritic tendril stars</h4><p class="paragraph">A dendritic tendril star is a dendritic tree with a depth greater than one, where the arms of the star are tendrils. We have detected 2 dendritic tendril stars in the graph, involving a total of 8 nodes (0.33%) and 16 edges (0.20%), with the largest one involving 5 nodes and 10 edges. The detected dendritic tendril stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tendril star starting from the root node ontology class (degree 40), and containing 5 nodes, with a maximal depth of 2, which are taxonomic rank, <a href='http://schema.org/Class' target='_blank' title='Go to SCHEMA to get more informations about schema:Class'>schema:Class</a>, <a href='http://www.w3.org/2002/07/owl#Class' target='_blank' title='Go to OWL to get more informations about owl:Class'>owl:Class</a>, relationship type and <a href='https://www.wikidata.org/wiki/Q427626' target='_blank' title='Go to WikiData to get more informations about WIKIDATA:Q427626'>WIKIDATA:Q427626</a>. Its edges have 3 edge types, which are mappings (2 edges), is_a (2 edges) and exact_mappings (2 edges).</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node phenotypic feature (degree 27), and containing 3 nodes, with a maximal depth of 2, which are clinical finding, behavioral feature and <a href='http://purl.obolibrary.org/obo/NBO_0000243' target='_blank' title='Go to Neuro Behavior Ontology to get more informations about NBO:0000243'>NBO:0000243</a>. Its edges have 2 edge types, which are exact_mappings (2 edges) and is_a (2 edges).</p></li></ol><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 77 tendrils in the graph, involving a total of 79 nodes (3.23%) and 158 edges (1.99%). The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node p value (degree 5), and containing 2 nodes, with a maximal depth of 2, which are adjusted p value and bonferonni adjusted p value. Its nodes have a single node type, which is float. Its edges have a single edge type, which is is_a.</p></li>
# <li><p class="paragraph">Tendril starting from the root node planetary entity (degree 4), and containing 2 nodes, with a maximal depth of 2, which are environmental feature and <a href='http://purl.obolibrary.org/obo/ENVO_01000254' target='_blank' title='Go to Environment Ontology to get more informations about ENVO:01000254'>ENVO:01000254</a>. Its edges have 2 edge types, which are exact_mappings (2 edges) and is_a.</p></li>
# <li><p class="paragraph">Tendril starting from the root node has decreased amount (degree 3), and containing a single other node, CL:has_low_plasma_membrane_amount. Its edges have a single edge type, which is narrow_mappings.</p></li>
# <li><p class="paragraph">Tendril starting from the root node disease to phenotypic feature association (degree 6), and containing a single other node, dcid:DiseaseSymptomAssociation. Its edges have a single edge type, which is close_mappings.</p></li>
# <li><p class="paragraph">Tendril starting from the root node is input of (degree 5), and containing a single other node, <a href='http://purl.obolibrary.org/obo/RO_0002352' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002352'>RO:0002352</a>. Its edges have a single edge type, which is exact_mappings.</p></li>
# <li><p class="paragraph">Tendril starting from the root node is splice site variant of (degree 5), and containing a single other node, <a href='http://www.sequenceontology.org/browser/current_svn/term/SO:0001629' target='_blank' title='Go to Sequence Ontology to get more informations about SO:0001629'>SO:0001629</a>. Its edges have a single edge type, which is exact_mappings.</p></li></ol><p class="paragraph">And other 71 tendrils.</p></div>

# %%
from grape.embedders import HyperSketching

GraphVisualizer(kg).fit_and_plot_all(HyperSketching(number_of_hops=6))
# Out:
# <p style="text-align: justify; word-break: break-all;"><b>TSNE decomposition and properties distribution of the KGBioLink graph using the HyperSketching node embedding:</b> <b>(a)</b> <i>Existent and non-existent edges</i>: 'Non-existent' in blue and 'Existent' in orange. The edge prediction form some clusters (Balanced accuracy: 79.25% ± 0.46%). <b>(b)</b> <i>Adamic-Adar heatmap</i>. This metric may be considered an edge prediction feature (Balanced accuracy: 56.53% ± 0.34%). <b>(c)</b> <i>Jaccard Coefficient heatmap</i>. This metric may be considered an edge prediction feature (Balanced accuracy: 56.71% ± 0.33%). <b>(d)</b> <i>Preferential Attachment heatmap</i>. This metric may be considered an edge prediction feature (Balanced accuracy: 58.40% ± 0.23%). <b>(e)</b> <i>Resource Allocation Index heatmap</i>. This metric may be considered an edge prediction feature (Balanced accuracy: 56.65% ± 0.23%). <b>(f)</b> <i>Edge types</i>: 'Narrow mappings' in blue, 'Is a' in orange, 'Exact mappings' in red, 'Mixins' in cyan, 'In subset' in green, 'Slots' in yellow, 'Defining slots' in purple, and Other 8 edge types in pink. The edge types do not appear to form recognizable clusters (Balanced accuracy: 34.33% ± 1.54%) <b>(g)</b> <i>Node degree distribution.</i> Node degrees are on the horizontal axis and node counts are on the vertical axis on a logarithmic scale. <b>(h)</b> <i>Adamic-Adar distribution.</i> Adamic-Adar values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale. <b>(j)</b> <i>Jaccard Coefficient distribution.</i> Jaccard Coefficient values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale. <b>(k)</b> <i>Preferential Attachment distribution.</i> Preferential Attachment values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale. <b>(i)</b> <i>Resource Allocation Index distribution.</i> Resource Allocation Index values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale.<br> In the heatmaps, <b>b</b>, <b>c</b>, <b>d</b>, and <b>e</b>, low and high values appear in red and blue hues, respectively. Intermediate values appear in either a yellow or cyan hue. The values are on a logarithmic scale The separability considerations for figures <b>a</b>, <b>b</b>, <b>c</b>, <b>d</b>, <b>e</b>, and <b>f</b>  derive from evaluating a Decision Tree trained on five Monte Carlo holdouts, with a 70/30 split between training and test sets. We have sampled 4.0 thousand existing and 4.0 thousand non-existing edges. We have sampled the non-existent edges' source and destination nodes by avoiding any disconnected nodes present in the graph to avoid biases.</p>

# %%
GraphVisualizer(kg).fit_and_plot_all("DeepWalk SkipGram")
# Out:
# /home/luca/anaconda3/envs/grape/lib/python3.11/site-packages/embiggen/utils/abstract_models/abstract_embedding_model.py:169: UserWarning: Please be advised that the KGBioLink graph contains 23 disconnected nodes. Consider that node embedding algorithms that only use topological information such as CBOW, GloVe, SPINE and SkipGram are not able to provide meaningful embeddings for these nodes, and their embedding will be generally far away from any other node. It is also possible that all disconnected nodes will receive a relatively similar node embedding. Consider dropping them by using the `graph.remove_disconnected_nodes()` method.
#   warnings.warn(
# <p style="text-align: justify; word-break: break-all;"><b>TSNE decomposition and properties distribution of the KGBioLink graph using the DeepWalk SkipGram node embedding:</b> <b>(a)</b> <i>Node degrees heatmap</i>. <b>(b)</b> <i>Node types</i>: 'Unknown' in blue, 'Named thing' in orange, 'Association' in red, 'Integer' in cyan, 'Genomic entity' in green, 'Sequence variant' in yellow, 'Publication' in purple, and Other 87 node types in pink. The node types concatenate do not appear to form recognizable clusters (Balanced accuracy: 19.54% ± 4.71%). <b>(c)</b> <i>Detected node ontologies</i>: 'Unknown' in blue, 'Relation Ontology' in orange, 'NCI Thesaurus OBO Edition' in red, 'Foundational Model of Anatomy Ontology (subset)' in cyan, 'Semantic Science' in green, 'WikiData' in yellow, 'Biological Spatial Ontology' in purple, and Other 74 ontologies in pink. The node ontologies concatenate do not appear to form recognizable clusters (Balanced accuracy: 25.77% ± 2.26%). <b>(d)</b> <i>Connected components</i>: 'Main component' in blue, 'Minor components' in orange, 'Singletons' in red, and 'Tuples' in cyan. The components concatenate form easily recognizable clusters (Balanced accuracy: 97.84% ± 4.31%). <b>(e)</b> <i>Existent and non-existent edges</i>: 'Non-existent' in blue and 'Existent' in orange. The edge prediction concatenate form some clusters (Balanced accuracy: 70.56% ± 1.02%). <b>(f)</b> <i>Adamic-Adar heatmap</i>. This metric may be considered an edge prediction feature (Balanced accuracy: 56.53% ± 0.34%). <b>(g)</b> <i>Jaccard Coefficient heatmap</i>. This metric may be considered an edge prediction feature (Balanced accuracy: 56.71% ± 0.33%). <b>(h)</b> <i>Preferential Attachment heatmap</i>. This metric may be considered an edge prediction feature (Balanced accuracy: 58.40% ± 0.23%). <b>(j)</b> <i>Resource Allocation Index heatmap</i>. This metric may be considered an edge prediction feature (Balanced accuracy: 56.65% ± 0.23%). <b>(k)</b> <i>Euclidean distance heatmap</i>. This metric is a good edge prediction feature (Balanced accuracy: 80.80% ± 0.65%). <b>(i)</b> <i>Cosine similarity heatmap</i>. This metric is a good edge prediction feature (Balanced accuracy: 87.62% ± 0.73%). Do note that the cosine similarity has been shifted from the range of [-1, 1] to the range [0, 2] to be visualized in a logarithmic heatmap. <b>(l)</b> <i>Edge types</i>: 'Narrow mappings' in blue, 'Is a' in orange, 'Exact mappings' in red, 'Mixins' in cyan, 'In subset' in green, 'Slots' in yellow, 'Defining slots' in purple, and Other 8 edge types in pink. The edge types concatenate do not appear to form recognizable clusters (Balanced accuracy: 36.67% ± 1.65%) <b>(m)</b> <i>Node degree distribution.</i> Node degrees are on the horizontal axis and node counts are on the vertical axis on a logarithmic scale. <b>(n)</b> <i>Adamic-Adar distribution.</i> Adamic-Adar values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale. <b>(o)</b> <i>Jaccard Coefficient distribution.</i> Jaccard Coefficient values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale. <b>(p)</b> <i>Preferential Attachment distribution.</i> Preferential Attachment values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale. <b>(q)</b> <i>Resource Allocation Index distribution.</i> Resource Allocation Index values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale. <b>(r)</b> <i>Euclidean distance distribution.</i> Euclidean distance values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale. <b>(s)</b> <i>Cosine similarity distribution.</i> Cosine similarity values are on the horizontal axis and edge counts are on the vertical axis on a logarithmic scale.<br> In the heatmaps, <b>a</b>, <b>f</b>, <b>g</b>, <b>h</b>, <b>j</b>, <b>k</b>, and <b>i</b>, low and high values appear in red an ...
